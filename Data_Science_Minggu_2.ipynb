# %% [markdown]
# <a href="https://colab.research.google.com/github/NeilR12/Multi/blob/main/Data_Science_Minggu_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset_contoh.csv')

# %%
df.head()
# Out:
#    NIM  Nama             Jurusan  IPK
# 0  101  Andi  Teknik Informatika   3.5
# 1  102  Budi    Sistem Informasi   3.2
# 2  103  Cici           Manajemen   3.8
# 3  104  Dedi  Teknik Informatika   2.9
# 4  105   Eka    Sistem Informasi   3.6

# %%
df.tail(3)
# Out:
#    NIM    Nama             Jurusan  IPK
# 5  106    Fani           Manajemen   3.4
# 6  107  Gilang  Teknik Informatika   3.7
# 7  108    Hani    Sistem Informasi   3.3

# %%
df.columns
# Out:
# Index(['NIM', 'Nama', 'Jurusan', 'IPK '], dtype='object')

# %%
df.shape
# Out:
# (8, 4)

# %%
df.dtypes
# Out:
# NIM          int64
# Nama        object
# Jurusan     object
# IPK        float64
# dtype: object

# %%
df['Jurusan'].unique()
# Out:
# array(['Teknik Informatika', 'Sistem Informasi', 'Manajemen'],
#       dtype=object)

# %%
df['Jurusan'].nunique()
# Out:
# 3

# %%
df['Jurusan'].value_counts()
# Out:
# Jurusan
# Teknik Informatika    3
# Sistem Informasi      3
# Manajemen             2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NIM      8 non-null      int64
#  1   Nama     8 non-null      object
#  2   Jurusan  8 non-null      object
#  3   IPK      8 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 388.0+ bytes

# %%
df.describe()
# Out:
#              NIM      IPK
# count    8.00000  8.000000
# mean   104.50000  3.425000
# std      2.44949  0.291548
# min    101.00000  2.900000
# 25%    102.75000  3.275000
# 50%    104.50000  3.450000
# 75%    106.25000  3.625000
# max    108.00000  3.800000

# %%
df['IPK'].mean()
# Out:
# np.float64(3.425)

# %%
df['IPK'].max()
# Out:
# 3.8

# %%
df['IPK'].min()
# Out:
# 2.9

# %%
df[df['IPK'] > 3.5]
# Out:
#    NIM    Nama             Jurusan  IPK
# 2  103    Cici           Manajemen  3.8
# 4  105     Eka    Sistem Informasi  3.6
# 6  107  Gilang  Teknik Informatika  3.7

# %%
df.sort_values('IPK', ascending=False)
# Out:
#    NIM    Nama             Jurusan  IPK
# 2  103    Cici           Manajemen  3.8
# 6  107  Gilang  Teknik Informatika  3.7
# 4  105     Eka    Sistem Informasi  3.6
# 0  101    Andi  Teknik Informatika  3.5
# 5  106    Fani           Manajemen  3.4
# 7  108    Hani    Sistem Informasi  3.3
# 1  102    Budi    Sistem Informasi  3.2
# 3  104    Dedi  Teknik Informatika  2.9

# %%
df.groupby('Jurusan')['IPK'].mean()
# Out:
# Jurusan
# Manajemen             3.600000
# Sistem Informasi      3.366667
# Teknik Informatika    3.366667
# Name: IPK, dtype: float64

# %%
df_nilai = pd.read_csv('data_nilai.csv')
df_nilai.head()
# Out:
#    NIM  MataKuliah  Nilai
# 0  101  Matematika     85
# 1  102  Statistika     78
# 2  103  Matematika     90
# 3  104   Algoritma     70
# 4  105  Statistika     88

# %%
df_nilai['MataKuliah'].unique()
# Out:
# array(['Matematika', 'Statistika', 'Algoritma'], dtype=object)

# %%
df_nilai['MataKuliah'].value_counts()
# Out:
# MataKuliah
# Matematika    3
# Statistika    3
# Algoritma     2
# Name: count, dtype: int64

# %%
df_nilai.groupby('MataKuliah')['Nilai'].mean()
# Out:
# MataKuliah
# Algoritma     67.5
# Matematika    89.0
# Statistika    82.0
# Name: Nilai, dtype: float64

# %%
df_gabungan = pd.merge(df, df_nilai, on='NIM')
df_gabungan.head()
# Out:
#    NIM  Nama             Jurusan  IPK  MataKuliah  Nilai
# 0  101  Andi  Teknik Informatika  3.5  Matematika     85
# 1  102  Budi    Sistem Informasi  3.2  Statistika     78
# 2  103  Cici           Manajemen  3.8  Matematika     90
# 3  104  Dedi  Teknik Informatika  2.9   Algoritma     70
# 4  105   Eka    Sistem Informasi  3.6  Statistika     88

# %%
df_gabungan[df_gabungan['MataKuliah'] == 'Matematika']
# Out:
#    NIM    Nama             Jurusan  IPK  MataKuliah  Nilai
# 0  101    Andi  Teknik Informatika  3.5  Matematika     85
# 2  103    Cici           Manajemen  3.8  Matematika     90
# 6  107  Gilang  Teknik Informatika  3.7  Matematika     92

# %%
df_gabungan.groupby('MataKuliah').agg({'Nilai': ['mean', 'max'], 'IPK': 'mean'})
# Out:
#            Nilai           IPK
#             mean max      mean
# MataKuliah
# Algoritma   67.5  70  3.150000
# Matematika  89.0  92  3.666667
# Statistika  82.0  88  3.366667

# %%
url_titanic = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df_titanic = pd.read_csv(url_titanic)
print(df_titanic.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
